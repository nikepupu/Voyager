# %%
a = {'bot1': [['onChat', {'onChat': 'No oak_log as fuel in inventory', 'voxels': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', ['oak_log', 9.486832980505138], 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush'], 'status': {'health': 1, 'food': 0, 'saturation': 0, 'position': {'x': -235.63684529574076, 'y': 32, 'z': -103.5}, 'velocity': {'x': 0, 'y': -0.0784000015258789, 'z': 0}, 'yaw': -3.0054565458281184, 'pitch': -0.8377580675888852, 'onGround': True, 'equipment': [None, None, None, None, 'feather', None], 'name': 'bot1', 'isInWater': False, 'isInLava': False, 'isCollidedHorizontally': False, 'isCollidedVertically': True, 'biome': 'plains', 'entities': {'sheep': 8.919389626629883, 'chicken': 9.723965822216405}, 'timeOfDay': 'day', 'inventoryUsed': 2, 'elapsedTime': 20}, 'inventory': {'feather': 1, 'chicken': 1}, 'nearbyChests': {'(-230, 33, -114)': {'cooked_chicken': 1}, '(-232, 42, -122)': '[]', '(-232, 42, -123)': '[]'}, 'blockRecords': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', 'oak_log', 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush', 'spruce_trapdoor', 'white_carpet', 'nether_brick_fence'], 'nearbyFurnaces': {'(-236, 32, -103)': []}}], ['observe', {'voxels': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', ['oak_log', 9.486832980505138], 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush'], 'status': {'health': 1, 'food': 0, 'saturation': 0, 'position': {'x': -235.63684529574076, 'y': 32, 'z': -103.5}, 'velocity': {'x': 0, 'y': -0.0784000015258789, 'z': 0}, 'yaw': -3.0054565458281184, 'pitch': -0.8377580675888852, 'onGround': True, 'equipment': [None, None, None, None, 'feather', None], 'name': 'bot1', 'isInWater': False, 'isInLava': False, 'isCollidedHorizontally': False, 'isCollidedVertically': True, 'biome': 'plains', 'entities': {'sheep': 8.919389626629883, 'chicken': 9.723965822216405}, 'timeOfDay': 'day', 'inventoryUsed': 2, 'elapsedTime': 82}, 'inventory': {'feather': 1, 'chicken': 1}, 'nearbyChests': {'(-230, 33, -114)': {'cooked_chicken': 1}, '(-232, 42, -122)': '[]', '(-232, 42, -123)': '[]'}, 'blockRecords': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', 'oak_log', 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush', 'spruce_trapdoor', 'white_carpet', 'nether_brick_fence'], 'nearbyFurnaces': {'(-236, 32, -103)': []}}]], 'bot2': [['onChat', {'onChat': 'No chicken to smelt in inventory', 'voxels': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', ['oak_log', 9.486832980505138], 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush'], 'status': {'health': 1, 'food': 0, 'saturation': 0, 'position': {'x': -235.6474279939433, 'y': 32, 'z': -103.5}, 'velocity': {'x': 0, 'y': -0.0784000015258789, 'z': 0}, 'yaw': -2.994690131226088, 'pitch': -0.8354349255909339, 'onGround': True, 'equipment': [None, None, None, None, 'feather', None], 'name': 'bot2', 'isInWater': False, 'isInLava': False, 'isCollidedHorizontally': False, 'isCollidedVertically': True, 'biome': 'plains', 'entities': {'sheep': 8.908873729176927, 'chicken': 9.714320929556466}, 'timeOfDay': 'day', 'inventoryUsed': 2, 'elapsedTime': 22}, 'inventory': {'feather': 1, 'oak_log': 1}, 'nearbyChests': {'(-230, 33, -114)': {'cooked_chicken': 1}, '(-232, 42, -122)': '[]', '(-232, 42, -123)': '[]'}, 'blockRecords': ['dirt', 'podzol', 'grass_block', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'dandelion', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', 'oak_log', 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush', 'spruce_trapdoor', 'white_carpet', 'nether_brick_fence'], 'nearbyFurnaces': {'(-236, 32, -103)': []}}], ['observe', {'voxels': ['dirt', 'grass_block', 'podzol', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'dandelion', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', ['oak_log', 9.486832980505138], 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush'], 'status': {'health': 1, 'food': 0, 'saturation': 0, 'position': {'x': -235.6474279939433, 'y': 32, 'z': -103.5}, 'velocity': {'x': 0, 'y': -0.0784000015258789, 'z': 0}, 'yaw': -2.994690131226088, 'pitch': -0.8354349255909339, 'onGround': True, 'equipment': [None, None, None, None, 'feather', None], 'name': 'bot2', 'isInWater': False, 'isInLava': False, 'isCollidedHorizontally': False, 'isCollidedVertically': True, 'biome': 'plains', 'entities': {'sheep': 8.908873729176927, 'chicken': 9.714320929556466}, 'timeOfDay': 'day', 'inventoryUsed': 2, 'elapsedTime': 81}, 'inventory': {'feather': 1, 'oak_log': 1}, 'nearbyChests': {'(-230, 33, -114)': {'cooked_chicken': 1}, '(-232, 42, -122)': '[]', '(-232, 42, -123)': '[]'}, 'blockRecords': ['dirt', 'podzol', 'grass_block', 'coarse_dirt', 'smooth_stone', 'stone_slab', 'grass', 'tall_grass', 'poppy', 'brick_stairs', 'bricks', 'quartz_slab', 'spruce_leaves', 'brick_slab', 'dandelion', 'cobblestone_wall', 'spruce_slab', 'jungle_fence', 'chain', 'quartz_pillar', 'brick_wall', 'polished_blackstone_brick_stairs', 'polished_blackstone_brick_slab', 'light_gray_stained_glass_pane', 'dirt_path', 'stone', 'diorite_wall', 'birch_fence', 'quartz_stairs', 'polished_blackstone_brick_wall', 'red_carpet', 'barrel', 'jungle_planks', 'smooth_quartz_slab', 'anvil', 'birch_trapdoor', 'potted_pink_tulip', 'potted_orange_tulip', 'potted_white_tulip', 'red_terracotta', 'gray_terracotta', 'dark_oak_fence', 'light_gray_terracotta', 'gray_wool', 'light_gray_carpet', 'end_rod', 'potted_bamboo', 'jungle_leaves', 'lantern', 'potted_red_tulip', 'skeleton_skull', 'polished_blackstone_slab', 'jungle_wall_sign', 'black_stained_glass_pane', 'furnace', 'jungle_stairs', 'potted_blue_orchid', 'dark_oak_pressure_plate', 'spruce_door', 'dark_oak_door', 'potted_poppy', 'bamboo', 'birch_slab', 'spruce_wall_sign', 'gray_carpet', 'polished_blackstone_pressure_plate', 'seagrass', 'chest', 'turtle_egg', 'cobblestone', 'birch_wall_sign', 'tripwire', 'tall_seagrass', 'water', 'smooth_quartz', 'potted_dark_oak_sapling', 'iron_trapdoor', 'oak_log', 'lily_pad', 'white_wool', 'quartz_block', 'oak_slab', 'bookshelf', 'potted_oxeye_daisy', 'polished_blackstone_button', 'spruce_button', 'tripwire_hook', 'scaffolding', 'sea_pickle', 'campfire', 'smoker', 'oak_wall_sign', 'diorite_slab', 'cake', 'spruce_log', 'potted_fern', 'potted_dead_bush', 'spruce_trapdoor', 'white_carpet', 'nether_brick_fence'], 'nearbyFurnaces': {'(-236, 32, -103)': []}}]], 'bot3': [['observe', {'voxels': ['dirt', 'podzol', 'coarse_dirt', 'grass_block', 'smooth_stone', 'stone_slab', 'brick_stairs', 'spruce_leaves', 'grass', 'spruce_log', 'dandelion', 'bricks', 'quartz_slab', 'stone', 'birch_fence', 'poppy', 'dirt_path', 'spruce_door', 'chest', 'tall_grass'], 'status': {'health': 20, 'food': 20, 'saturation': 5, 'position': {'x': -216.5, 'y': 32, 'z': -52.5}, 'velocity': {'x': 0, 'y': -0.0784000015258789, 'z': 0}, 'yaw': -3.1415926535804193, 'pitch': -0.5105088062083416, 'onGround': True, 'equipment': [None, None, None, None, None, None], 'name': 'bot3', 'isInWater': False, 'isInLava': False, 'isCollidedHorizontally': False, 'isCollidedVertically': True, 'biome': 'plains', 'entities': {}, 'timeOfDay': 'day', 'inventoryUsed': 0, 'elapsedTime': 0}, 'inventory': {}, 'nearbyChests': {'(-217, 32, -51)': {'egg': 2, 'mutton': 2, 'white_wool': 1, 'feather': 3}}, 'blockRecords': ['dirt', 'podzol', 'coarse_dirt', 'grass_block', 'smooth_stone', 'stone_slab', 'brick_stairs', 'spruce_leaves', 'grass', 'spruce_log', 'dandelion', 'bricks', 'quartz_slab', 'stone', 'birch_fence', 'poppy', 'dirt_path', 'spruce_door', 'chest', 'tall_grass'], 'nearbyFurnaces': {}}]]}

# %%
for event in a['bot1']:
    if event[0] == 'onChat':
        message = 'For bot1 ' +   event[1]['onChat']
        print(message)
# Out:
# For bot1 No oak_log as fuel in inventory
